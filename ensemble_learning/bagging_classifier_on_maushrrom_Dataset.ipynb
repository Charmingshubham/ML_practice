# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df['class'] = df['class'].map(lambda x: 0 if x=='p' else 1 )

# %%
df.head()
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      0         x           s         n       t    p               f
# 1      1         x           s         y       t    a               f
# 2      1         b           s         w       t    l               f
# 3      0         x           y         w       t    p               f
# 4      1         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
X = df.iloc[:,1:]
y = df.iloc[:,0]

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
X = encoder.fit_transform(X)

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score
dt = DecisionTreeClassifier(max_depth=4)
dt.fit(X_train,y_train)
y_pred = dt.predict(X_test)
print('accuracy of a dt',r2_score(y_test,y_pred))
# Out:
# accuracy of a dt 0.9654898320151207

# %%
from sklearn.ensemble import BaggingClassifier
bag = BaggingClassifier(
    estimator = DecisionTreeClassifier(),
    n_estimators = 50,
    max_samples = 0.3,
    bootstrap = True,
    random_state = 42
)

# %%
bag.fit(X_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=0.3,
#                   n_estimators=50, random_state=42)

# %%
y_pred = bag.predict(X_test)

# %%
print('accuracy is',r2_score(y_test,y_pred))
# Out:
# accuracy is 1.0

# %% [markdown]
# pasting

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=False,
    random_state=42,
    verbose = 1,
    n_jobs=-1
)

# %%
bag.fit(X_train,y_train)
y_pred = bag.predict(X_test)
# Out:
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done   2 out of  12 | elapsed:    2.6s remaining:   13.2s
# [Parallel(n_jobs=12)]: Done  12 out of  12 | elapsed:    2.6s finished
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done   2 out of  12 | elapsed:    0.0s remaining:    0.6s
# [Parallel(n_jobs=12)]: Done  12 out of  12 | elapsed:    0.2s finished

# %%
print("Pasting classifier",r2_score(y_test,y_pred)
# Out:
# Pasting classifier 1.0

# %% [markdown]
# Random Subspaces

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=1.0,
    bootstrap=False,
    max_features=0.5,
    bootstrap_features=True,
    random_state=42
)

# %%
bag.fit(X_train,y_train)
y_pred = bag.predict(X_test)

# %%
print("Random Subspaces classifier",r2_score(y_test,y_pred))
# Out:
# Random Subspaces classifier 1.0

# %% [markdown]
# Random Patches

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    max_features=0.5,
    bootstrap_features=True,
    random_state=42
)
     

bag.fit(X_train,y_train)
y_pred = bag.predict(X_test)

# %%
print("Random Patches classifier",r2_score(y_test,y_pred))
# Out:
# Random Patches classifier 1.0

# %% [markdown]
# OOB Score

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    oob_score=True,
    random_state=42
)
     

bag.fit(X_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=0.25,
#                   n_estimators=500, oob_score=True, random_state=42)

# %%
bag.oob_score_
# Out:
# 0.9993845206954917

# %%
y_pred = bag.predict(X_test)
print("Accuracy",r2_score(y_test,y_pred))
# Out:
# Accuracy 1.0

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    'n_estimators':[10,50,100,300,500],
    'max_samples':[0.2,0.3,0.4,0.5,0.25],
    'bootstrap':[True,False],
    'max_features':[0.1,0.3,0.4,0.7,1.0]
    
}

# %%
search = GridSearchCV(BaggingClassifier(), parameters, cv=5)

# %%
search.fit(X_train,y_train)

# %%
search.best_params_
search.best_score_

# %%
search.best_params_
